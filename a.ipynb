# %%
# !pip install httpx

# %%
from app.integrations.sec.client import SECClient

c=SECClient()
d=c.get_company_submissions('789019')
print(d['name'])
print(d['cik'])
print(d['tickers'])

c.close()
# Out:
# MICROSOFT CORP
# 0000789019
# ['MSFT']

# %%
d['filings']["recent"].keys()
# Out:
# dict_keys(['accessionNumber', 'filingDate', 'reportDate', 'acceptanceDateTime', 'act', 'form', 'fileNumber', 'filmNumber', 'items', 'core_type', 'size', 'isXBRL', 'isInlineXBRL', 'isXBRLNumeric', 'primaryDocument', 'primaryDocDescription'])
